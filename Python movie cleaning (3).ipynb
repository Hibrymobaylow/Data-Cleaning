# %% [markdown]
# In \[161\]:
#
#     import pandas as pd
#     import numpy as np
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#     import warnings
#     import ast
#     warnings.filterwarnings('ignore')
#     %matplotlib inline
#     sns.set()
#
# ## importing raw data<a href="#importing-raw-data" class="anchor-link">¶</a>
#
# In \[162\]:
#
#     raw_data = pd.read_csv('movies.csv')
#
# ## Rename working data<a href="#Rename-working-data" class="anchor-link">¶</a>
#
# In \[163\]:
#
#     data = raw_data.copy()
#     data.head()
#
# Out\[163\]:
#
# |     | MOVIES                              | YEAR        | GENRE                           | RATING | ONE-LINE                                           | STARS                                              | VOTES   | RunTime | Gross |
# |-----|-------------------------------------|-------------|---------------------------------|--------|----------------------------------------------------|----------------------------------------------------|---------|---------|-------|
# | 0   | Blood Red Sky                       | \(2021\)    | \\nAction, Horror, Thriller     | 6.1    | \\nA woman with a mysterious illness is forced ... | \\n Director:\\nPeter Thorwarth\\n\| \\n Star...   | 21,062  | 121.0   | NaN   |
# | 1   | Masters of the Universe: Revelation | (2021– )    | \\nAnimation, Action, Adventure | 5.0    | \\nThe war for Eternia begins again in what may... | \\n \\n Stars:\\nChris Wood, \\nSara...            | 17,870  | 25.0    | NaN   |
# | 2   | The Walking Dead                    | (2010–2022) | \\nDrama, Horror, Thriller      | 8.2    | \\nSheriff Deputy Rick Grimes wakes up from a c... | \\n \\n Stars:\\nAndrew Lincoln, \\n...            | 885,805 | 44.0    | NaN   |
# | 3   | Rick and Morty                      | (2013– )    | \\nAnimation, Adventure, Comedy | 9.2    | \\nAn animated series that follows the exploits... | \\n \\n Stars:\\nJustin Roiland, \\n...            | 414,849 | 23.0    | NaN   |
# | 4   | Army of Thieves                     | \(2021\)    | \\nAction, Crime, Horror        | NaN    | \\nA prequel, set before the events of Army of ... | \\n Director:\\nMatthias Schweighöfer\\n\| \\n ... | NaN     | NaN     | NaN   |
#
# ## Checking data information<a href="#Checking-data-information" class="anchor-link">¶</a>
#
# In \[164\]:
#
#     data.info()
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 9999 entries, 0 to 9998
#     Data columns (total 9 columns):
#      #   Column    Non-Null Count  Dtype
#     ---  ------    --------------  -----
#      0   MOVIES    9999 non-null   object
#      1   YEAR      9355 non-null   object
#      2   GENRE     9919 non-null   object
#      3   RATING    8179 non-null   float64
#      4   ONE-LINE  9999 non-null   object
#      5   STARS     9999 non-null   object
#      6   VOTES     8179 non-null   object
#      7   RunTime   7041 non-null   float64
#      8   Gross     460 non-null    object
#     dtypes: float64(2), object(7)
#     memory usage: 703.2+ KB
#
# In \[165\]:
#
#     data.describe()
#
# Out\[165\]:
#
# |       | RATING      | RunTime     |
# |-------|-------------|-------------|
# | count | 8179.000000 | 7041.000000 |
# | mean  | 6.921176    | 68.688539   |
# | std   | 1.220232    | 47.258056   |
# | min   | 1.100000    | 1.000000    |
# | 25%   | 6.200000    | 36.000000   |
# | 50%   | 7.100000    | 60.000000   |
# | 75%   | 7.800000    | 95.000000   |
# | max   | 9.900000    | 853.000000  |
#
# ## checking for null values<a href="#checking-for-null-values" class="anchor-link">¶</a>
#
# In \[166\]:
#
#     data.isnull().sum()
#
# Out\[166\]:
#
#     MOVIES         0
#     YEAR         644
#     GENRE         80
#     RATING      1820
#     ONE-LINE       0
#     STARS          0
#     VOTES       1820
#     RunTime     2958
#     Gross       9539
#     dtype: int64
#
# # Cleaning data<a href="#Cleaning-data" class="anchor-link">¶</a>
#
# In \[167\]:
#
#     data = data.drop_duplicates(subset=['MOVIES'])
#     data
#
# Out\[167\]:
#
# |      | MOVIES                              | YEAR        | GENRE                           | RATING | ONE-LINE                                           | STARS                                              | VOTES   | RunTime | Gross |
# |------|-------------------------------------|-------------|---------------------------------|--------|----------------------------------------------------|----------------------------------------------------|---------|---------|-------|
# | 0    | Blood Red Sky                       | \(2021\)    | \\nAction, Horror, Thriller     | 6.1    | \\nA woman with a mysterious illness is forced ... | \\n Director:\\nPeter Thorwarth\\n\| \\n Star...   | 21,062  | 121.0   | NaN   |
# | 1    | Masters of the Universe: Revelation | (2021– )    | \\nAnimation, Action, Adventure | 5.0    | \\nThe war for Eternia begins again in what may... | \\n \\n Stars:\\nChris Wood, \\nSara...            | 17,870  | 25.0    | NaN   |
# | 2    | The Walking Dead                    | (2010–2022) | \\nDrama, Horror, Thriller      | 8.2    | \\nSheriff Deputy Rick Grimes wakes up from a c... | \\n \\n Stars:\\nAndrew Lincoln, \\n...            | 885,805 | 44.0    | NaN   |
# | 3    | Rick and Morty                      | (2013– )    | \\nAnimation, Adventure, Comedy | 9.2    | \\nAn animated series that follows the exploits... | \\n \\n Stars:\\nJustin Roiland, \\n...            | 414,849 | 23.0    | NaN   |
# | 4    | Army of Thieves                     | \(2021\)    | \\nAction, Crime, Horror        | NaN    | \\nA prequel, set before the events of Army of ... | \\n Director:\\nMatthias Schweighöfer\\n\| \\n ... | NaN     | NaN     | NaN   |
# | ...  | ...                                 | ...         | ...                             | ...    | ...                                                | ...                                                | ...     | ...     | ...   |
# | 9935 | The Imperfects                      | (2021– )    | \\nAdventure, Drama, Fantasy    | NaN    | \\nAdd a Plot\\n                                   | \\n \\n Stars:\\nMorgan Taylor Camp...             | NaN     | NaN     | NaN   |
# | 9964 | AlRawabi School for Girls           | \(2021\)    | \\nDrama                        | NaN    | \\nAdd a Plot\\n                                   | \\n Director:\\nTima Shomali\\n\| \\n Stars:\\...  | NaN     | NaN     | NaN   |
# | 9993 | Totenfrau                           | (2022– )    | \\nDrama, Thriller              | NaN    | \\nAdd a Plot\\n                                   | \\n Director:\\nNicolai Rohde\\n\| \\n Stars:...   | NaN     | NaN     | NaN   |
# | 9995 | Arcane                              | (2021– )    | \\nAnimation, Action, Adventure | NaN    | \\nAdd a Plot\\n                                   | \\n                                                | NaN     | NaN     | NaN   |
# | 9996 | Heart of Invictus                   | (2022– )    | \\nDocumentary, Sport           | NaN    | \\nAdd a Plot\\n                                   | \\n Director:\\nOrlando von Einsiedel\\n\| \\n ... | NaN     | NaN     | NaN   |
#
# 6817 rows × 9 columns
#
# ## Cleaning 'YEAR' column<a href="#Cleaning-&#39;YEAR&#39;-column" class="anchor-link">¶</a>
#
# In \[168\]:
#
#     data["YEAR"] = data["YEAR"].str.replace('[^a-zA-Z0-9]', '')
#     data["YEAR"]=data["YEAR"].apply(lambda x : str(x))
#     data["YEAR"]=data["YEAR"].apply(lambda x : (x[0:4] + ", " + x[4:8]) if len(x)>4 else x)
#     data.drop_duplicates()
#     data.dropna(subset = 'YEAR' )
#     data
#
# Out\[168\]:
#
# |      | MOVIES                              | YEAR       | GENRE                           | RATING | ONE-LINE                                           | STARS                                              | VOTES   | RunTime | Gross |
# |------|-------------------------------------|------------|---------------------------------|--------|----------------------------------------------------|----------------------------------------------------|---------|---------|-------|
# | 0    | Blood Red Sky                       | 2021       | \\nAction, Horror, Thriller     | 6.1    | \\nA woman with a mysterious illness is forced ... | \\n Director:\\nPeter Thorwarth\\n\| \\n Star...   | 21,062  | 121.0   | NaN   |
# | 1    | Masters of the Universe: Revelation | 2021       | \\nAnimation, Action, Adventure | 5.0    | \\nThe war for Eternia begins again in what may... | \\n \\n Stars:\\nChris Wood, \\nSara...            | 17,870  | 25.0    | NaN   |
# | 2    | The Walking Dead                    | 2010, 2022 | \\nDrama, Horror, Thriller      | 8.2    | \\nSheriff Deputy Rick Grimes wakes up from a c... | \\n \\n Stars:\\nAndrew Lincoln, \\n...            | 885,805 | 44.0    | NaN   |
# | 3    | Rick and Morty                      | 2013       | \\nAnimation, Adventure, Comedy | 9.2    | \\nAn animated series that follows the exploits... | \\n \\n Stars:\\nJustin Roiland, \\n...            | 414,849 | 23.0    | NaN   |
# | 4    | Army of Thieves                     | 2021       | \\nAction, Crime, Horror        | NaN    | \\nA prequel, set before the events of Army of ... | \\n Director:\\nMatthias Schweighöfer\\n\| \\n ... | NaN     | NaN     | NaN   |
# | ...  | ...                                 | ...        | ...                             | ...    | ...                                                | ...                                                | ...     | ...     | ...   |
# | 9935 | The Imperfects                      | 2021       | \\nAdventure, Drama, Fantasy    | NaN    | \\nAdd a Plot\\n                                   | \\n \\n Stars:\\nMorgan Taylor Camp...             | NaN     | NaN     | NaN   |
# | 9964 | AlRawabi School for Girls           | 2021       | \\nDrama                        | NaN    | \\nAdd a Plot\\n                                   | \\n Director:\\nTima Shomali\\n\| \\n Stars:\\...  | NaN     | NaN     | NaN   |
# | 9993 | Totenfrau                           | 2022       | \\nDrama, Thriller              | NaN    | \\nAdd a Plot\\n                                   | \\n Director:\\nNicolai Rohde\\n\| \\n Stars:...   | NaN     | NaN     | NaN   |
# | 9995 | Arcane                              | 2021       | \\nAnimation, Action, Adventure | NaN    | \\nAdd a Plot\\n                                   | \\n                                                | NaN     | NaN     | NaN   |
# | 9996 | Heart of Invictus                   | 2022       | \\nDocumentary, Sport           | NaN    | \\nAdd a Plot\\n                                   | \\n Director:\\nOrlando von Einsiedel\\n\| \\n ... | NaN     | NaN     | NaN   |
#
# 6817 rows × 9 columns
#
# ## Cleaning '\\n' from data<a href="#Cleaning-&#39;%5Cn&#39;-from-data" class="anchor-link">¶</a>
#
# In \[188\]:
#
#     data['GENRE'] = data['GENRE'].str.strip('\n')
#     data['ONE-LINE'] = data['ONE-LINE'].str.strip('\n')
#     data
#
# Out\[188\]:
#
# |      | MOVIES                                           | YEAR       | GENRE                        | RATING | ONE-LINE                                          | VOTES   | RunTime | Gross | directors                     | stars                                             |
# |------|--------------------------------------------------|------------|------------------------------|--------|---------------------------------------------------|---------|---------|-------|-------------------------------|---------------------------------------------------|
# | 0    | Blood Red Sky                                    | 2021       | Action, Horror, Thriller     | 6.1    | A woman with a mysterious illness is forced in... | 21,062  | 121.0   | NaN   | Peter Thorwarth               | Peri Baumeister Carl Anton Koch Alexander Sche... |
# | 1    | Masters of the Universe: Revelation              | 2021       | Animation, Action, Adventure | 5.0    | The war for Eternia begins again in what may b... | 17,870  | 25.0    | NaN   | None                          | Chris Wood Sarah Michelle Gellar Lena Headey M... |
# | 2    | The Walking Dead                                 | 2010, 2022 | Drama, Horror, Thriller      | 8.2    | Sheriff Deputy Rick Grimes wakes up from a com... | 885,805 | 44.0    | NaN   | None                          | Andrew Lincoln Norman Reedus Melissa McBride L... |
# | 3    | Rick and Morty                                   | 2013       | Animation, Adventure, Comedy | 9.2    | An animated series that follows the exploits o... | 414,849 | 23.0    | NaN   | None                          | Justin Roiland Chris Parnell Spencer Grammer S... |
# | 5    | Outer Banks                                      | 2020       | Action, Crime, Drama         | 7.6    | A group of teenagers from the wrong side of th... | 25,858  | 50.0    | NaN   | None                          | Chase Stokes Madelyn Cline Madison Bailey Jona... |
# | ...  | ...                                              | ...        | ...                          | ...    | ...                                               | ...     | ...     | ...   | ...                           | ...                                               |
# | 9814 | This Is a Robbery: The World's Biggest Art Heist | 2021       | Documentary, Crime, History  | 7.3    | A museum guard buzzes in two men dressed as co... | 175     | 53.0    | NaN   | Colin Barnicle                | Nancy Clougherty Justin Stratman Anne Hawley S... |
# | 9837 | Dead Places                                      | 2021       | Adventure, Horror, Thriller  | 6.4    | While filming a social media stunt, a vlogger ... | 28      | NaN     | NaN   | Gareth Crocker Fred Wolmarans | Nambitha BenMazwi Nozethu Bonyongo Allen Booi ... |
# | 9901 | Modern Family                                    | 2009, 2020 | Comedy, Drama, Romance       | 8.2    | Jay must adapt to his young new wife, Gloria a... | 3,404   | 23.0    | NaN   | Jason Winer                   | Ed ONeill Sofa Vergara Julie Bowen Ty Burrell     |
# | 9915 | Girl From Nowhere                                | 2018       | Crime, Drama, Fantasy        | 7.8    | Nanai is a popular boy in school with a bad ha... | 183     | NaN     | NaN   | Pairach Khumwan               | Chicha Amatayakul Bekah Jung Yuuki Luna Tris Ren  |
# | 9934 | Master of None                                   | 2015       | Comedy, Drama                | 5.8    | Now a bestselling author, Denise leads a quiet... | 1,173   | 55.0    | NaN   | Aziz Ansari                   | Naomi Ackie Lena Waithe Aziz Ansari Aysha Kala    |
#
# 5804 rows × 10 columns
#
# In \[170\]:
#
#     data.isnull().sum()
#
# Out\[170\]:
#
#     MOVIES         0
#     YEAR           0
#     GENRE         71
#     RATING      1002
#     ONE-LINE       0
#     STARS          0
#     VOTES       1002
#     RunTime     1512
#     Gross       6365
#     dtype: int64
#
# ## Spliting stars column into directors and stars<a href="#Spliting-stars-column-into-directors-and-stars" class="anchor-link">¶</a>
#
# In \[171\]:
#
#     data[['directors', 'stars']] = data['STARS'].str.split('Stars:', expand= True)
#     data.drop(columns='STARS', inplace=True)
#     data
#
# Out\[171\]:
#
# |      | MOVIES                              | YEAR       | GENRE                        | RATING | ONE-LINE                                          | VOTES   | RunTime | Gross | directors                                          | stars                                                |
# |------|-------------------------------------|------------|------------------------------|--------|---------------------------------------------------|---------|---------|-------|----------------------------------------------------|------------------------------------------------------|
# | 0    | Blood Red Sky                       | 2021       | Action, Horror, Thriller     | 6.1    | A woman with a mysterious illness is forced in... | 21,062  | 121.0   | NaN   | \\n Director:\\nPeter Thorwarth\\n\| \\n           | \\nPeri Baumeister, \\nCarl Anton Koch, \\nAlexan... |
# | 1    | Masters of the Universe: Revelation | 2021       | Animation, Action, Adventure | 5.0    | The war for Eternia begins again in what may b... | 17,870  | 25.0    | NaN   | \\n \\n                                            | \\nChris Wood, \\nSarah Michelle Gellar, \\nLena ... |
# | 2    | The Walking Dead                    | 2010, 2022 | Drama, Horror, Thriller      | 8.2    | Sheriff Deputy Rick Grimes wakes up from a com... | 885,805 | 44.0    | NaN   | \\n \\n                                            | \\nAndrew Lincoln, \\nNorman Reedus, \\nMelissa M... |
# | 3    | Rick and Morty                      | 2013       | Animation, Adventure, Comedy | 9.2    | An animated series that follows the exploits o... | 414,849 | 23.0    | NaN   | \\n \\n                                            | \\nJustin Roiland, \\nChris Parnell, \\nSpencer G... |
# | 4    | Army of Thieves                     | 2021       | Action, Crime, Horror        | NaN    | A prequel, set before the events of Army of th... | NaN     | NaN     | NaN   | \\n Director:\\nMatthias Schweighöfer\\n\| \\n     | \\nMatthias Schweighöfer, \\nNathalie Emmanuel, ...  |
# | ...  | ...                                 | ...        | ...                          | ...    | ...                                               | ...     | ...     | ...   | ...                                                | ...                                                  |
# | 9935 | The Imperfects                      | 2021       | Adventure, Drama, Fantasy    | NaN    | Add a Plot                                        | NaN     | NaN     | NaN   | \\n \\n                                            | \\nMorgan Taylor Campbell, \\nChris Cope, \\nIñak... |
# | 9964 | AlRawabi School for Girls           | 2021       | Drama                        | NaN    | Add a Plot                                        | NaN     | NaN     | NaN   | \\n Director:\\nTima Shomali\\n\| \\n              | \\nSalsabiela A., \\nJoanna Arida, \\nYara Mustaf... |
# | 9993 | Totenfrau                           | 2022       | Drama, Thriller              | NaN    | Add a Plot                                        | NaN     | NaN     | NaN   | \\n Director:\\nNicolai Rohde\\n\| \\n             | \\nFelix Klare, \\nRomina Küper, \\nAnna Maria Mü... |
# | 9995 | Arcane                              | 2021       | Animation, Action, Adventure | NaN    | Add a Plot                                        | NaN     | NaN     | NaN   | \\n                                                | None                                                 |
# | 9996 | Heart of Invictus                   | 2022       | Documentary, Sport           | NaN    | Add a Plot                                        | NaN     | NaN     | NaN   | \\n Director:\\nOrlando von Einsiedel\\n\| \\n ... | None                                                 |
#
# 6817 rows × 10 columns
#
# ## Cleaning directors and star columns<a href="#Cleaning-directors-and-star-columns" class="anchor-link">¶</a>
#
# In \[176\]:
#
#     data['directors'] = data['directors'].str.split(':', expand=True)
#     data.replace(r'\n', '', regex=True)
#     data["directors"] = data["directors"].str.replace('[^a-zA-Z0-9 ]','')
#     data["stars"] = data["stars"].str.replace('[^a-zA-Z0-9 ]','')
#     data
#
# Out\[176\]:
#
# |      | MOVIES                              | YEAR       | GENRE                        | RATING | ONE-LINE                                          | VOTES   | RunTime | Gross | directors                  | stars                                             |
# |------|-------------------------------------|------------|------------------------------|--------|---------------------------------------------------|---------|---------|-------|----------------------------|---------------------------------------------------|
# | 0    | Blood Red Sky                       | 2021       | Action, Horror, Thriller     | 6.1    | A woman with a mysterious illness is forced in... | 21,062  | 121.0   | NaN   | Peter Thorwarth            | Peri Baumeister Carl Anton Koch Alexander Sche... |
# | 1    | Masters of the Universe: Revelation | 2021       | Animation, Action, Adventure | 5.0    | The war for Eternia begins again in what may b... | 17,870  | 25.0    | NaN   | None                       | Chris Wood Sarah Michelle Gellar Lena Headey M... |
# | 2    | The Walking Dead                    | 2010, 2022 | Drama, Horror, Thriller      | 8.2    | Sheriff Deputy Rick Grimes wakes up from a com... | 885,805 | 44.0    | NaN   | None                       | Andrew Lincoln Norman Reedus Melissa McBride L... |
# | 3    | Rick and Morty                      | 2013       | Animation, Adventure, Comedy | 9.2    | An animated series that follows the exploits o... | 414,849 | 23.0    | NaN   | None                       | Justin Roiland Chris Parnell Spencer Grammer S... |
# | 4    | Army of Thieves                     | 2021       | Action, Crime, Horror        | NaN    | A prequel, set before the events of Army of th... | NaN     | NaN     | NaN   | Matthias Schweighfer       | Matthias Schweighfer Nathalie Emmanuel Ruby O ... |
# | ...  | ...                                 | ...        | ...                          | ...    | ...                                               | ...     | ...     | ...   | ...                        | ...                                               |
# | 9935 | The Imperfects                      | 2021       | Adventure, Drama, Fantasy    | NaN    | Add a Plot                                        | NaN     | NaN     | NaN   | None                       | Morgan Taylor Campbell Chris Cope Iaki Godoy R... |
# | 9964 | AlRawabi School for Girls           | 2021       | Drama                        | NaN    | Add a Plot                                        | NaN     | NaN     | NaN   | Tima Shomali               | Salsabiela A Joanna Arida Yara Mustafa Rakeen ... |
# | 9993 | Totenfrau                           | 2022       | Drama, Thriller              | NaN    | Add a Plot                                        | NaN     | NaN     | NaN   | Nicolai Rohde              | Felix Klare Romina Kper Anna Maria Mhe Robert ... |
# | 9995 | Arcane                              | 2021       | Animation, Action, Adventure | NaN    | Add a Plot                                        | NaN     | NaN     | NaN   | None                       | None                                              |
# | 9996 | Heart of Invictus                   | 2022       | Documentary, Sport           | NaN    | Add a Plot                                        | NaN     | NaN     | NaN   | Orlando von Einsiedel Star | None                                              |
#
# 6817 rows × 10 columns
#
# ## Movies with Gross data as mwg<a href="#Movies-with-Gross-data-as-mwg" class="anchor-link">¶</a>
#
# In \[177\]:
#
#     mwg = data[data['Gross'].notnull()].reset_index(drop=True)
#     mwg['Gross'] = mwg['Gross'].str.replace('[^0-9]', '')
#     mwg
#
# Out\[177\]:
#
# |     | MOVIES                                            | YEAR    | GENRE                       | RATING | ONE-LINE                                          | VOTES     | RunTime | Gross | directors            | stars                                             |
# |-----|---------------------------------------------------|---------|-----------------------------|--------|---------------------------------------------------|-----------|---------|-------|----------------------|---------------------------------------------------|
# | 0   | The Hitman's Bodyguard                            | 2017    | Action, Comedy, Crime       | 6.9    | The world's top bodyguard gets a new client, a... | 205,979   | 118.0   | 7547  | Patrick Hughes       | Ryan Reynolds Samuel L Jackson Gary Oldman Elo... |
# | 1   | Jurassic Park                                     | 1993    | Action, Adventure, Sci-Fi   | 8.1    | A pragmatic paleontologist visiting an almost ... | 897,444   | 127.0   | 40245 | Steven Spielberg     | Sam Neill Laura Dern Jeff Goldblum Richard Att... |
# | 2   | Don't Breathe                                     | 2016    | Crime, Horror, Thriller     | 7.1    | Hoping to walk away with a massive fortune, a ... | 237,601   | 88.0    | 8922  | Fede Alvarez         | Stephen Lang Jane Levy Dylan Minnette Daniel Z... |
# | 3   | The Lord of the Rings: The Fellowship of the Ring | 2001    | Action, Adventure, Drama    | 8.8    | A meek Hobbit from the Shire and eight compani... | 1,713,028 | 178.0   | 31554 | Peter Jackson        | Elijah Wood Ian McKellen Orlando Bloom Sean Bean  |
# | 4   | Escape Room                                       | I201, 9 | Action, Adventure, Horror   | 6.4    | Six strangers find themselves in a maze of dea... | 99,351    | 99.0    | 5701  | Adam Robitel         | Taylor Russell Logan Miller Jay Ellis Tyler La... |
# | ... | ...                                               | ...     | ...                         | ...    | ...                                               | ...       | ...     | ...   | ...                  | ...                                               |
# | 447 | Vidal Sassoon: The Movie                          | 2010    | Documentary                 | 6.5    | Vidal Sassoon is more than just a hairdresser-... | 245       | 90.0    | 009   | Craig Teper          | Beverly Adams Elgin Charles Grace Coddington M... |
# | 448 | Men at Lunch                                      | 2012    | Documentary, Mystery        | 6.3    | The story of "Lunch atop a Skyscraper," the ic... | 331       | 75.0    | 000   | Sen Cualin           | Fionnula Flanagan Peter Quinn Ric Burns Christ... |
# | 449 | Decoding Deepak                                   | 2012    | Documentary                 | 5.5    | Deepak Chopra's son, Gotham, spends a year tra... | 124       | 83.0    | 001   | Gotham Chopra        | Deepak Chopra Gotham Chopra                       |
# | 450 | Theo Who Lived                                    | 2016    | Documentary                 | 6.8    | A documentary on American journalist Theo Padn... | 111       | 86.0    | 001   | David Schisgall Star | None                                              |
# | 451 | Southern Justice                                  | 2006    | Action, Adventure, Thriller | 3.1    | M.D. Selig's feature thriller, SOUTHERN JUSTIC... | 126       | 96.0    | 014   | MD Selig             | MD Selig Michael Childers Lisa Robert Rico Cymone |
#
# 452 rows × 10 columns
#
# ## Droping null values<a href="#Droping-null-values" class="anchor-link">¶</a>
#
# In \[187\]:
#
#     data = data.dropna(subset = ['VOTES','RATING','GENRE'])
#
# ## Change Gross data type to float<a href="#Change-Gross-data-type-to-float" class="anchor-link">¶</a>
#
# In \[182\]:
#
#     mwg['Gross'] = mwg['Gross'].astype('float')
#     mwg.info()
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 452 entries, 0 to 451
#     Data columns (total 10 columns):
#      #   Column     Non-Null Count  Dtype
#     ---  ------     --------------  -----
#      0   MOVIES     452 non-null    object
#      1   YEAR       452 non-null    object
#      2   GENRE      452 non-null    object
#      3   RATING     452 non-null    float64
#      4   ONE-LINE   452 non-null    object
#      5   VOTES      452 non-null    object
#      6   RunTime    452 non-null    float64
#      7   Gross      452 non-null    float64
#      8   directors  452 non-null    object
#      9   stars      448 non-null    object
#     dtypes: float64(3), object(7)
#     memory usage: 35.4+ KB
#
# In \[189\]:
#
#     genres = data["GENRE"].value_counts().head(10).plot(kind='bar')
#     plt.ylabel('Count')
#     plt.legend(labels ='Count')
#     plt.show()
#
# ![](data:image/png;base64,...%0A)
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# In \[ \]:
